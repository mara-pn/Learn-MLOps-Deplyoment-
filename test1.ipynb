# %% [markdown]
# # Test Project

# %%
print("This is a test project to learn MLOps Deployment from PROD to DEV!")
# Out:
# This is a test project to learn MLOps Deployment from PROD to DEV!

# %%
print("Feel free to make changes as you wish!")
# Out:
# Feel free to make changes as you wish!

# %%
print("here are the new changes you were waiting for so desperately!")
# Out:
# here are the new changes you were waiting for so desperately!
